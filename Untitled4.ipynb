# %% [markdown]
# <a href="https://colab.research.google.com/github/harshpillai0212/newds/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("Anime.csv")
data
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type  Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# ...

# %%
import pandas as pd
data=pd.read_excel("Anime.xlsx")
data
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type  Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread("Untitled.jpg")
plt.imshow(img)

# %%
import pandas as pd
df=pd.DataFrame({"Roll no":[41,42,43,44,45,43],
                 "Name":['Harshith','Pratik','Harsh','Shubham','Akshay','Harsh'],
                 "Marks":[22,18,25,21,20,25]})
print(df)
# Out:
#    Roll no      Name  Marks
# 0       41  Harshith     22
# 1       42    Pratik     18
# 2       43     Harsh     25
# 3       44   Shubham     21
# 4       45    Akshay     20
# 5       43     Harsh     25

# %%
df.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.describe()
# Out:
#          Roll no      Marks
# count   5.000000   5.000000
# mean   43.000000  21.200000
# std     1.581139   2.588436
# min    41.000000  18.000000
# 25%    42.000000  20.000000
# 50%    43.000000  21.000000
# 75%    44.000000  22.000000
# max    45.000000  25.000000

# %%
df.describe(include="object")
# Out:
#          Name
# count       6
# unique      5
# top     Harsh
# freq        2

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Harsh       2
# Harshith    1
# Pratik      1
# Shubham     1
# Akshay      1
# Name: Name, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-53-48d031cc9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
import seaborn as sns
cor=df.corr()
sns.heatmap(cor,annot=True,fmt=".2f",cmap='viridis')
# Out:
# <ipython-input-66-72fd270157bb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
# <Axes: >

# %%
df['Roll no'].var()
# Out:
# 2.0

# %%
df.mean()
# Out:
# <ipython-input-72-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no    43.000000
# Marks      21.833333
# dtype: float64

# %%
df.cov()
# Out:
# <ipython-input-77-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          Roll no     Marks
# Roll no      2.0 -0.200000
# Marks       -0.2  7.766667
